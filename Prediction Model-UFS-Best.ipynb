# %%
### Import Statements ###
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_selection import RFE
import seaborn as sns
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.feature_selection import SelectKBest, chi2
# %matplotlib inline

# %%
df = pd.read_csv('criminal_train.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45718 entries, 0 to 45717
# Data columns (total 72 columns):
# PERID        45718 non-null int64
# IFATHER      45718 non-null int64
# NRCH17_2     45718 non-null int64
# IRHHSIZ2     45718 non-null int64
# IIHHSIZ2     45718 non-null int64
# IRKI17_2     45718 non-null int64
# IIKI17_2     45718 non-null int64
# IRHH65_2     45718 non-null int64
# IIHH65_2     45718 non-null int64
# PRXRETRY     45718 non-null int64
# PRXYDATA     45718 non-null int64
# MEDICARE     45718 non-null int64
# CAIDCHIP     45718 non-null int64
# CHAMPUS      45718 non-null int64
# PRVHLTIN     45718 non-null int64
# GRPHLTIN     45718 non-null int64
# HLTINNOS     45718 non-null int64
# HLCNOTYR     45718 non-null int64
# HLCNOTMO     45718 non-null int64
# HLCLAST      45718 non-null int64
# HLLOSRSN     45718 non-null int64
# HLNVCOST     45718 non-null int64
# HLNVOFFR     45718 non-null int64
# HLNVREF      45718 non-null int64
# HLNVNEED     45718 non-null int64
# HLNVSOR      45718 non-null int64
# IRMCDCHP     45718 non-null int64
# IIMCDCHP     45718 non-null int64
# IRMEDICR     45718 non-null int64
# IIMEDICR     45718 non-null int64
# IRCHMPUS     45718 non-null int64
# IICHMPUS     45718 non-null int64
# IRPRVHLT     45718 non-null int64
# IIPRVHLT     45718 non-null int64
# IROTHHLT     45718 non-null int64
# IIOTHHLT     45718 non-null int64
# HLCALLFG     45718 non-null int64
# HLCALL99     45718 non-null int64
# ANYHLTI2     45718 non-null int64
# IRINSUR4     45718 non-null int64
# IIINSUR4     45718 non-null int64
# OTHINS       45718 non-null int64
# CELLNOTCL    45718 non-null int64
# CELLWRKNG    45718 non-null int64
# IRFAMSOC     45718 non-null int64
# IIFAMSOC     45718 non-null int64
# IRFAMSSI     45718 non-null int64
# IIFAMSSI     45718 non-null int64
# IRFSTAMP     45718 non-null int64
# IIFSTAMP     45718 non-null int64
# IRFAMPMT     45718 non-null int64
# IIFAMPMT     45718 non-null int64
# IRFAMSVC     45718 non-null int64
# IIFAMSVC     45718 non-null int64
# IRWELMOS     45718 non-null int64
# IIWELMOS     45718 non-null int64
# IRPINC3      45718 non-null int64
# IRFAMIN3     45718 non-null int64
# IIPINC3      45718 non-null int64
# IIFAMIN3     45718 non-null int64
# GOVTPROG     45718 non-null int64
# POVERTY3     45718 non-null int64
# TOOLONG      45718 non-null int64
# TROUBUND     45718 non-null int64
# PDEN10       45718 non-null int64
# COUTYP2      45718 non-null int64
# MAIIN102     45718 non-null int64
# AIIND102     45718 non-null int64
# ANALWT_C     45718 non-null float64
# VESTR        45718 non-null int64
# VEREP        45718 non-null int64
# Criminal     45718 non-null int64
# dtypes: float64(1), int64(71)
# memory usage: 25.1 MB

# %%
'''from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(df)
scaled_features = scaler.transform(df)
df_feat = pd.DataFrame(scaled_features,columns=df.columns)
df_feat.head()'''

# %%
'''from sklearn.decomposition import PCA
pca = PCA(n_components=50)
pca.fit(scaled_data)
x_pca = pd.DataFrame(pca.transform(scaled_data))
'''

# %%
for i in df.columns:
    df[i][df[i] < 0] = df[i].mean()
# Out:
# /home/sahil/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df
# Out:
#           PERID  IFATHER  NRCH17_2  IRHHSIZ2  IIHHSIZ2  IRKI17_2  IIKI17_2  \
# 0      25095143      4.0       2.0       4.0       1.0       3.0       1.0
# 1      13005143      4.0       1.0       3.0       1.0       2.0       1.0
# 2      67415143      4.0       1.0       2.0       1.0       2.0       1.0
# 3      70925143      4.0       0.0       2.0       1.0       1.0       1.0
# 4      75235143      1.0       0.0       6.0       1.0       4.0       1.0
# 5      47745143      4.0       0.0       2.0       1.0       1.0       1.0
# 6      33145143      4.0       3.0       6.0       1.0       4.0       1.0
# 7      63765143      4.0       2.0       4.0       1.0       3.0       1.0
# 8      57796143      4.0       1.0       3.0       1.0       2.0       1.0
# 9      66416143      4.0       0.0       1.0       1.0       1.0       1.0
# 10     51916143      4.0       0.0       1.0       1.0       1.0       1.0
# 11     40016143      4.0       0.0       4.0       1.0       3.0       1.0
# 12     99116143      4.0       0.0       2.0       1.0       1.0       1.0
# 13     85326143      1.0       0.0       3.0       1.0       2.0       1.0
# 14     63336143      1.0       0.0       5.0       1.0       4.0       1.0
# 15     64946143      4.0       3.0       5.0       1.0       4.0       1.0
# 16     73856143      4.0       0.0       2.0       1.0       1.0       1.0
# 17     82956143      4.0       2.0       4.0       1.0       3.0       1.0
# 18     65276143      4.0       2.0       3.0       1.0       3.0       1.0
# 19     58307143      1.0       0.0       4.0       1.0       3.0       1.0
# 20     67407143      1.0       0.0       4.0       1.0       3.0       1.0
# 21     83427143      4.0       1.0       3.0       1.0       2.0       1.0
# 22     68447143      1.0       0.0       5.0       1.0       3.0       1.0
# 23     65177143      4.0       0.0       2.0       1.0       1.0       1.0
# 24     77787143      1.0       0.0       6.0       1.0       4.0       1.0
# 25     96887143      4.0       0.0       4.0       1.0       2.0       1.0
# 26     46218143      4.0       0.0       3.0       1.0       2.0       3.0
# 27     15938143      4.0       0.0       1.0       1.0       1.0       1.0
# 28     15268143      4.0       0.0       3.0       1.0       1.0       1.0
# 29     79868143      1.0       0.0       4.0       1.0       3.0       1.0
# ...         ...      ...       ...       ...       ...       ...       ...
# 45688  14130679      4.0       0.0       3.0       1.0       2.0       1.0
# 45689  21950679      4.0       1.0       3.0       1.0       2.0       1.0
# 45690  65360679      1.0       0.0       4.0       1.0       3.0       1.0
# 45691  29960679      4.0       0.0       4.0       1.0       1.0       1.0
# 45692  22470679      4.0       2.0       3.0       1.0       3.0       1.0
# 45693  67970679      4.0       0.0       2.0       1.0       1.0       1.0
# 45694  95501679      4.0       2.0       4.0       1.0       3.0       1.0
# 45695  30001679      4.0       3.0       6.0       1.0       4.0       1.0
# 45696  64411679      4.0       0.0       3.0       1.0       1.0       1.0
# 45697  34221679      4.0       0.0       3.0       1.0       1.0       1.0
# 45698  11331679      4.0       0.0       4.0       1.0       1.0       1.0
# 45699  19671679      1.0       0.0       4.0       1.0       3.0       1.0
# 45700  37681679      1.0       0.0       3.0       1.0       2.0       1.0
# 45701  49002679      4.0       0.0       4.0       1.0       1.0       1.0
# 45702  67632679      4.0       3.0       5.0       1.0       4.0       1.0
# 45703  15352679      1.0       0.0       4.0       1.0       3.0       1.0
# 45704  71752679      4.0       3.0       6.0       1.0       4.0       1.0
# 45705  86062679      4.0       1.0       2.0       1.0       2.0       1.0
# 45706  17772679      4.0       0.0       3.0       1.0       1.0       1.0
# 45707  29382679      4.0       2.0       4.0       1.0       3.0       1.0
# 45708  99193679      1.0       0.0       6.0       1.0       4.0       1.0
# 45709  23313679      2.0       0.0       3.0       1.0       3.0       1.0
# 45710  90423679      4.0       1.0       2.0       1.0       2.0       1.0
# 45711  88143679      1.0       0.0       3.0       1.0       2.0       1.0
# 45712  75253679      4.0       2.0       4.0       1.0       3.0       1.0
# 45713  29663679      4.0       1.0       3.0       1.0       2.0       1.0
# 45714  43073679      4.0       0.0       3.0       1.0       1.0       1.0
# 45715  52173679      4.0       0.0       6.0       1.0       4.0       1.0
# 45716  29283679      4.0       0.0       1.0       1.0       1.0       1.0
# 45717  87483679      4.0       0.0       4.0       1.0       1.0       1.0
#
#        IRHH65_2  IIHH65_2  PRXRETRY    ...     TOOLONG  TROUBUND  PDEN10  \
# 0           1.0       1.0      99.0    ...         1.0       2.0     1.0
# 1           1.0       1.0      99.0    ...         2.0       2.0     2.0
# 2           1.0       1.0      99.0    ...         2.0       2.0     2.0
# 3           1.0       1.0      99.0    ...         2.0       2.0     1.0
# 4           1.0       1.0      99.0    ...         2.0       2.0     2.0
# 5           1.0       1.0      99.0    ...         2.0       2.0     2.0
# 6           1.0       1.0      99.0    ...         2.0       2.0     2.0
# 7           1.0       1.0      99.0    ...         2.0       2.0     2.0
# 8           1.0       1.0      99.0    ...         2.0       2.0     2.0
# 9           2.0       1.0      99.0    ...         2.0       2.0     1.0
# 10          1.0       1.0      99.0    ...        98.0      98.0     2.0
# 11          1.0       1.0      99.0    ...         2.0       2.0     1.0
# 12          2.0       1.0      99.0    ...         2.0       2.0     2.0
# 13          1.0       1.0      99.0    ...         2.0       2.0     1.0
# 14          1.0       1.0      99.0    ...         2.0       2.0     1.0
# 15          1.0       1.0      99.0    ...         2.0       2.0     1.0
# 16          1.0       1.0      99.0    ...         2.0       2.0     2.0
# 17          1.0       1.0      99.0    ...         2.0       2.0     3.0
# 18          1.0       1.0      99.0    ...         2.0       2.0     2.0
# 19          1.0       1.0      99.0    ...         2.0       2.0     2.0
# 20          1.0       1.0      99.0    ...         2.0       2.0     2.0
# 21          1.0       1.0      99.0    ...         2.0       2.0     2.0
# 22          2.0       1.0      99.0    ...         2.0       1.0     1.0
# 23          3.0       1.0      99.0    ...         2.0       2.0     2.0
# 24          1.0       1.0      99.0    ...         2.0       2.0     2.0
# 25          1.0       1.0      99.0    ...         2.0       2.0     1.0
# 26          1.0       3.0      99.0    ...         2.0       2.0     2.0
# 27          1.0       1.0      99.0    ...         2.0       2.0     2.0
# 28          1.0       1.0      99.0    ...         2.0       2.0     2.0
# 29          1.0       1.0      99.0    ...         2.0       2.0     2.0
# ...         ...       ...       ...    ...         ...       ...     ...
# 45688       1.0       1.0      99.0    ...         2.0       2.0     2.0
# 45689       1.0       1.0      99.0    ...         2.0       2.0     2.0
# 45690       1.0       1.0      99.0    ...         2.0       2.0     2.0
# 45691       1.0       1.0      99.0    ...         2.0       2.0     2.0
# 45692       1.0       1.0      99.0    ...         2.0       2.0     2.0
# 45693       1.0       1.0      99.0    ...         2.0       2.0     1.0
# 45694       1.0       1.0      99.0    ...         2.0       2.0     2.0
# 45695       1.0       1.0      99.0    ...         2.0       2.0     1.0
# 45696       1.0       1.0      99.0    ...         2.0       2.0     1.0
# 45697       2.0       1.0      99.0    ...         2.0       2.0     1.0
# 45698       1.0       1.0      99.0    ...         2.0       2.0     1.0
# 45699       1.0       1.0      99.0    ...         2.0       2.0     1.0
# 45700       1.0       1.0      99.0    ...         2.0       1.0     2.0
# 45701       1.0       1.0      99.0    ...         2.0       2.0     1.0
# 45702       1.0       1.0      99.0    ...         2.0       2.0     1.0
# 45703       1.0       1.0      99.0    ...         2.0       2.0     1.0
# 45704       1.0       1.0      99.0    ...         2.0       2.0     2.0
# 45705       1.0       1.0      99.0    ...         2.0       2.0     2.0
# 45706       2.0       1.0      99.0    ...         2.0       2.0     1.0
# 45707       1.0       1.0      99.0    ...         2.0       2.0     3.0
# 45708       1.0       1.0      99.0    ...         2.0       2.0     2.0
# 45709       1.0       1.0      99.0    ...         2.0       2.0     2.0
# 45710       1.0       1.0      99.0    ...         2.0       2.0     1.0
# 45711       1.0       1.0      99.0    ...         2.0       2.0     1.0
# 45712       1.0       1.0      99.0    ...         2.0       2.0     2.0
# 45713       1.0       1.0      99.0    ...         2.0       2.0     2.0
# 45714       2.0       1.0       2.0    ...         2.0       2.0     1.0
# 45715       2.0       1.0      99.0    ...         2.0       2.0     1.0
# 45716       1.0       1.0      99.0    ...         2.0       2.0     2.0
# 45717       1.0       1.0      99.0    ...         2.0       2.0     1.0
#
#        COUTYP2  MAIIN102  AIIND102      ANALWT_C    VESTR  VEREP  Criminal
# 0          1.0       2.0       2.0   3884.805998  40026.0    1.0         0
# 1          3.0       2.0       2.0   1627.108106  40015.0    2.0         1
# 2          3.0       2.0       2.0   4344.957980  40024.0    1.0         0
# 3          1.0       2.0       2.0    792.521931  40027.0    1.0         0
# 4          2.0       2.0       2.0   1518.118526  40001.0    2.0         0
# 5          3.0       2.0       2.0   9129.229124  40035.0    2.0         0
# 6          2.0       2.0       2.0   6561.895497  40043.0    2.0         0
# 7          2.0       2.0       2.0   3341.718873  40006.0    2.0         0
# 8          1.0       2.0       2.0   3384.147888  40021.0    2.0         0
# 9          1.0       2.0       2.0   2636.943978  40006.0    1.0         0
# 10         3.0       2.0       2.0   3026.110863  40044.0    1.0         0
# 11         1.0       2.0       2.0   4196.225953  40025.0    2.0         0
# 12         2.0       2.0       2.0  20905.427440  40042.0    1.0         0
# 13         1.0       2.0       2.0   2671.376188  40035.0    2.0         0
# 14         1.0       2.0       2.0   1430.775669  40020.0    1.0         0
# 15         1.0       2.0       2.0   1041.374975  40004.0    2.0         0
# 16         2.0       2.0       2.0   5014.378391  40023.0    1.0         0
# 17         3.0       2.0       2.0   4757.271596  40033.0    1.0         0
# 18         2.0       2.0       2.0   2784.880401  40025.0    2.0         0
# 19         3.0       2.0       2.0    330.258076  40036.0    1.0         0
# 20         3.0       2.0       2.0   2398.833215  40028.0    2.0         0
# 21         2.0       2.0       2.0   4247.334140  40008.0    2.0         0
# 22         1.0       2.0       2.0   2432.035890  40007.0    2.0         0
# 23         3.0       2.0       2.0   9429.142633  40010.0    2.0         0
# 24         3.0       1.0       1.0    791.405193  40012.0    2.0         0
# 25         1.0       2.0       2.0    751.207301  40046.0    1.0         0
# 26         3.0       2.0       2.0   3327.695904  40042.0    2.0         0
# 27         2.0       1.0       1.0   7913.574798  40012.0    2.0         0
# 28         3.0       2.0       2.0    416.917733  40036.0    1.0         0
# 29         2.0       2.0       2.0    432.992914  40016.0    2.0         0
# ...        ...       ...       ...           ...      ...    ...       ...
# 45688      2.0       1.0       1.0    777.818127  40032.0    1.0         0
# 45689      2.0       2.0       2.0   3151.572267  40039.0    1.0         0
# 45690      3.0       2.0       2.0   1096.831803  40017.0    2.0         0
# 45691      2.0       2.0       2.0    423.457314  40013.0    1.0         0
# 45692      2.0       2.0       2.0    889.149627  40002.0    2.0         0
# 45693      1.0       2.0       2.0   1827.943610  40005.0    1.0         0
# 45694      2.0       2.0       2.0   1620.395136  40041.0    2.0         0
# 45695      1.0       2.0       2.0  13406.081270  40028.0    2.0         0
# 45696      1.0       2.0       2.0   6337.800897  40029.0    2.0         0
# 45697      1.0       2.0       2.0   2784.636409  40050.0    1.0         0
# 45698      1.0       2.0       2.0   8943.198244  40019.0    1.0         0
# 45699      1.0       2.0       2.0   1234.591124  40006.0    2.0         0
# 45700      2.0       2.0       2.0    316.479457  40010.0    1.0         0
# 45701      1.0       2.0       2.0   2980.588149  40010.0    1.0         0
# 45702      1.0       2.0       2.0   7102.143169  40049.0    1.0         0
# 45703      1.0       2.0       2.0   2973.000430  40019.0    1.0         0
# 45704      3.0       2.0       2.0    531.775773  40036.0    1.0         0
# 45705      2.0       2.0       2.0   1284.461723  40042.0    2.0         0
# 45706      1.0       2.0       2.0  26956.734140  40037.0    2.0         0
# 45707      3.0       2.0       2.0    325.704473  40004.0    1.0         0
# 45708      3.0       2.0       2.0   1966.301610  40001.0    1.0         0
# 45709      3.0       2.0       2.0    516.659176  40023.0    1.0         1
# 45710      1.0       2.0       2.0   7845.356253  40049.0    2.0         1
# 45711      1.0       2.0       2.0   4307.472836  40020.0    2.0         0
# 45712      2.0       2.0       2.0    682.483078  40048.0    1.0         0
# 45713      2.0       2.0       2.0  11212.106960  40011.0    1.0         0
# 45714      1.0       2.0       2.0   5733.239983  40035.0    2.0         0
# 45715      1.0       2.0       2.0   1490.027425  40040.0    1.0         0
# 45716      2.0       2.0       2.0   3847.137418  40050.0    1.0         0
# 45717      1.0       2.0       2.0  11357.793720  40018.0    2.0         0
#
# [45718 rows x 72 columns]

# %%
test = SelectKBest(score_func=chi2, k=65)
fit = test.fit(df.drop('Criminal',axis=1),df['Criminal'])
#print(len(fit.scores_))
features = fit.transform(df.drop('Criminal',axis=1))
# summarize selected features
print(features.shape)
dfy = pd.DataFrame(data=features,columns=range(1,66))
dfyc = pd.DataFrame(df['Criminal'],columns=['66'])
dfy = pd.concat([dfy,df['Criminal']],axis=1)
# Out:
# (45718, 65)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df.drop('Criminal',axis=1), 
                                                    df['Criminal'], test_size=0.2, 
                                                    random_state=101)

# %%
from sklearn.ensemble import RandomForestRegressor,RandomForestClassifier
#rf = RandomForestClassifier() #default 
rf = RandomForestClassifier(n_estimators=500)

# %%
rf.fit(dfy.drop('Criminal',axis=1),dfy['Criminal'])
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=500, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)

# %%
dft = pd.read_csv('criminal_test.csv')
dft. head()
# Out:
#       PERID  IFATHER  NRCH17_2  IRHHSIZ2  IIHHSIZ2  IRKI17_2  IIKI17_2  \
# 0  66583679        4         0         4         1         2         1
# 1  35494679        4         0         4         1         1         1
# 2  79424679        2         0         3         1         2         1
# 3  11744679        4         0         6         1         2         1
# 4  31554679        1         0         4         1         3         1
#
#    IRHH65_2  IIHH65_2  PRXRETRY  ...    POVERTY3  TOOLONG  TROUBUND  PDEN10  \
# 0         1         1        99  ...           2        2         2       1
# 1         1         1        99  ...           3        2         2       1
# 2         1         1        99  ...           1        2         2       2
# 3         1         1        99  ...           3        2         2       1
# 4         1         1        99  ...           3        2         1       1
#
#    COUTYP2  MAIIN102  AIIND102      ANALWT_C  VESTR  VEREP
# 0        1         2         2  16346.795400  40020      1
# 1        1         2         2   3008.863906  40044      2
# 2        2         2         2    266.952503  40040      2
# 3        1         2         2   5386.928199  40017      1
# 4        1         2         2    173.489895  40017      1
#
# [5 rows x 71 columns]

# %%
test = SelectKBest(score_func=chi2, k=65)
#print(len(fit.scores_))
features = fit.transform(dft)
# summarize selected features
print(features.shape)
dfyt = pd.DataFrame(data=features,columns=range(1,66))
# Out:
# (11430, 65)

# %%
final_predict = pd.DataFrame(rf.predict(dfyt),columns=['Criminal'])
result = pd.DataFrame(dft['PERID'],columns=['PERID'])
result = pd.concat([result,final_predict],axis=1)
result['Criminal'].value_counts()
# Out:
# 0    10765
# 1      665
# Name: Criminal, dtype: int64

# %%
result.to_csv('final_predictions.csv',index=False)

# %%
dfs = pd.read_csv('final_predictions.csv')
